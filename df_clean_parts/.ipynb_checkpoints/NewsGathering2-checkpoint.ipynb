# %% [markdown]
# # Parte 3: Recolección de información
# ### Web Scraping a "Semana" para investigación referente a los cambios climáticos en Colombia

# %% [markdown]
# ### Paso 1: Importación de librerias

# %%
import pandas as pd
import time
import random
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.support import expected_conditions as EC
from random import shuffle

# %% [markdown]
# ### Paso 2: Definición de opciones para el navegador

# %%
chrome_options = Options()
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument("--start-maximized")
chrome_options.add_argument('--window-size=1420,1080')
chrome_options.add_argument('--disable-dev-shm-usage')
chrome_options.add_argument('--disable-gpu')
chrome_options.add_argument("--disable-notifications")
chrome_options.add_argument("--remote-debugging-port=9222")
chrome_options.add_experimental_option("excludeSwitches", ["enable-automation"])
chrome_options.add_experimental_option('useAutomationExtension', False)
chrome_options.add_experimental_option("excludeSwitches", ["disable-popup-blocking"])

# %% [markdown]
# ### Paso 3: Definición de clase personalizada

# %%
# Clase para personalización
class bcolors:
    WARNING = '\033[93m'
    FAIL = '\033[91m'

# Control de errores
try:   
    # Definición de función
    def Seconds(result):
        hours = round(result/3600)
        minutes = round((result - (hours * 3600))/60)
        seconds = round(result - ((hours * 3600) + (minutes * 60)))
        if seconds < 0: seconds = seconds*-1
        if minutes < 0: minutes = minutes*-1
        final_time = "El sitema tardó: " + str(hours) + " horas " + str(minutes) + " minutos " + str(seconds) + " segundos en finalizar su ejeción"
        return final_time
    
except Exception as e: 
    print(bcolors.FAIL + "Revisa el error => ", e) # Impresión del error personalizado

# %% [markdown]
# ### Paso 4: Lectura de archivo de noticias

# %%
# Definición de la clase
class IterableClass:
    
    # Función inicial o constructor
    def __init__(self, list_values = None): # None es para que sea opcional
        self.list_values = list_values
        self.dateframe = pd.read_csv(r'df_clean_2.csv') # lectura del archivo
        self.i = 0
        
    # Retornar un iterador
    def __iter__(self):
        return self
    
    # Retorna un elemento del contenedor
    def __next__(self):
        if self.i >= len(self.list_values):
            print("\nNo hay más valores a recorrer... ⬇")
            raise StopIteration
            
        item = self.list_values[self.i]
        self.i += 1
        return item

# %% [markdown]
# ### Paso 5: Instacia del objeto e impresión del DataFrame

# %%
# Instancia del objeto
IC = IterableClass()

# 5.1. Eliminación de columna que se creo en por error "Unnamed: 0" .drop('Unnamed: 0', axis=1)
# 5.2. Reseteo de index por la acción de combinación de DataFrames .reset_index().drop(['index'], axis=1)
IC.dateframe.drop('Unnamed: 0', axis=1).reset_index().drop(['index'], axis=1)
# Out:
#                                           headers_text  \
# 0    Duque convoca coalición mundial para proteger ...
# 1    Las economías no pueden seguir dependiendo de ...
# 2    Fuertes vientos continuarán este jueves y vier...
# 3    El conflicto del hombre con la fauna silvestre...
# 4    ¿Qué es el Observatorio Ambiental de Bogotá y ...
# ..                                                 ...
# 295  Clima en crisis: las serias consecuencias del ...
# 296  Época de heladas: Las zonas de Colombia en las...
# 297  Mientras el frío azota a América del Norte, en...
# 298  Increíble: se registró la misma temperatura en...
# 299  La Antártida argentina alcanzó temperatura réc...
#
#                                           headers_link
# 0    https://www.semana.com/medio-ambiente/articulo...
# 1    https://www.semana.com/medio-ambiente/articulo...
# 2    https://www.semana.com/fuertes-vientos-continu...
# 3    https://www.semana.com/sostenible/medio-ambien...
# 4    https://www.semana.com/sostenible/medio-ambien...
# ..                                                 ...
# 295  https://www.semana.com/sostenible/medio-ambien...
# 296  https://www.semana.com/temperaturas-podrian-ll...
# 297  https://www.semana.com/mientras-el-frio-azota-...
# 298  https://www.semana.com/temperatura-de-la-antar...
# 299  https://www.semana.com/nacion/medio-ambiente/a...
#
# [300 rows x 2 columns]

# %% [markdown]
# ### Paso 6: Definición de función para unificar los diferentes parrafos de la noticia

# %%
def JoinParagraphs(paragraphs):
    TextParagraphs = ""
    for paragraph in paragraphs:
        TextParagraphs = TextParagraphs + paragraph.text
        
    return TextParagraphs

# %% [markdown]
# ### Paso 7: Definición de función para unificar los diferentes temas de la noticia

# %%
def JoinThemes(themes):
    TextThemes = ""
    for theme in themes:
        TextThemes = TextThemes + theme.text + ", "
    return TextThemes

# %% [markdown]
# ### Paso 8: Recolección de información para cada noticia

# %%
# 8.1 Declaraciones de variables
titles = []
summaries = []
authors = []
dates = []
paragraphs = []
themes = []

# %%
# PASO 8.2: Aviso para el usuario final de que se inicio el web-scraping --------------------------------------------------------------#
print("Se inició el Web Scraping a 'Semana', por favor espere...") # Mensaje para visualización del inicio del proceso

# 8.2.1 Variable para definir el inicio de tiempo en ejecución
start = time.time()
# Out:
# Se inició el Web Scraping a 'Semana', por favor espere...

# %%
# PASO 8.3 Estructura base para acceder a la página en cuestión ----------------------------------------------------------------------#
service = Service(executable_path=r'../../chromedriver-win64/chromedriver.exe') # Creación del servicio mediante el driver
options = webdriver.ChromeOptions() # Definición de variable con las opciones para chrome
driver = webdriver.Chrome(service=service, options=options) # Creación del objeto del WebDriver

# Asignación de dataframe a una variable
links = IC.dateframe

# Control del error al momento de finalizar el páginado
try:
    
    # Iteración para acceso a los links del dataframe
    for i in range(len(links)):
        
        news = {
            "titles" : [],
            "summaries" : [],
            "authors" : [],
            "dates" : [],
            "paragraphs" : [],
            "themes" : [],
        }
        
        # Acceso a cada link del dataframe
        driver.get(links.iloc[i]['headers_link'])

        # Títulos
        # ****************************************************************************************************************
        title = driver.find_elements(By.XPATH, '//*[@id="fusion-app"]/div/main/article/div/div[2]/h1')
        if title:
            for i in title:
                print(titles.append(i.text))
        else: titles.append('...')
        # ****************************************************************************************************************

        # Resúmenes
        # ****************************************************************************************************************
        summary = driver.find_elements(By.XPATH, '//*[@id="fusion-app"]/div/main/article/div/div[2]/p')
        if summary: 
            for i in summary:
                print(summaries.append(i.text))
        else: summaries.append('...')
        # ****************************************************************************************************************

        # Autor
        # ****************************************************************************************************************
        date_a = driver.find_elements(By.XPATH, '//*[@id="fusion-app"]/div/main/article/div/div[2]/div[2]/div')
        if date_a: 
            if len(date_a) == 1:
                author_a = driver.find_elements(By.XPATH, '//*[@id="fusion-app"]/div/main/article/div/div[2]/div[2]/a/div')
                if author_a:
                    for i in author_a:
                        print(authors.append(i.text))
                else: authors.append('...')
            elif len(date_a) > 1:
                author_b = driver.find_elements(By.XPATH, '//*[@id="fusion-app"]/div/main/article/div/div[2]/div[2]/div[1]')
                if author_b:
                    for i in author_b:
                        print(authors.append(i.text))
                else: authors.append('...')
            else: authors.append('...')
        else: authors.append('...')
        # Test
        author_a = None
        author_b = None
        date_a = None
        # ****************************************************************************************************************

        # Fecha
        # ****************************************************************************************************************
        date_a = driver.find_elements(By.XPATH, '//*[@id="fusion-app"]/div/main/article/div/div[2]/div[2]/div')
        if date_a: 
            if len(date_a) == 1:
                if date_a:
                    for i in date_a:
                        print(dates.append(i.text))
                else: dates.append('...')
            elif len(date_a) > 1:
                date_b = driver.find_elements(By.XPATH, '//*[@id="fusion-app"]/div/main/article/div/div[2]/div[2]/div[2]')
                if date_b:
                    for i in date_b:
                        print(dates.append(i.text))
                else: dates.append('...')
            else: dates.append('...')
        else: dates.append('...')
        # Test
        author_a = None
        date_a = None
        date_b = None
        # ****************************************************************************************************************
        
        # Parrafos
        # ****************************************************************************************************************
        paragraphs_a = driver.find_elements(By.CLASS_NAME, 'prose')
        if paragraphs_a: 
            if len(paragraphs_a) > 1:
                paragraphs.append(JoinParagraphs(paragraphs_a))
            else:
                paragraphs.append(paragraphs_a[0].text)
        else: paragraphs.append('...')
        # ****************************************************************************************************************

        # Temas
        # ****************************************************************************************************************
        tags = driver.find_elements(By.CSS_SELECTOR, 'a.inline-block')
        if tags: 
            if len(tags) > 1:
                themes.append(JoinThemes(tags))
            else:
                themes.append(tags[0].text)
        else: themes.append('...')
        # ****************************************************************************************************************
                
        # Construcción del diccionario 
        news = {
            "titles" : titles,
            "summaries" : summaries,
            "authors" : authors,
            "dates" : dates,
            "paragraphs" : paragraphs,
            "themes" : themes
        }

        # Construcción inicial del dataframe
        df = pd.DataFrame(news)

        # (Opcional) Modo DEBUG, sirve para validar como el DataFrame se está llenando según las iteraciones
        display(df)
    else:
        driver.quit();
        
except Exception as e:
    display("Exception :", e)
    driver.quit() 
except NoSuchElementException as nse:
    display("NoSuchElementException :", nse)
    driver.quit()
except TimeoutException as tim:
    display("TimeoutException :", tim)
    driver.quit()
# Out:
# None
# None
# None
#                                               titles  \
# 0  Duque convoca coalición mundial para proteger ...
#
#                                            summaries authors  \
# 0  En su intervención en la Cumbre sobre Bosques ...     ...
#
#                       dates  \
# 0  23 de septiembre de 2019
#
#                                           paragraphs  \
# 0  Durante su intervención en la Cumbre sobre los...
#
#                                               themes
# 0  Juventud se manifiesta en cumbre por el clima,...
# None
# None
# None
#                                               titles  \
# 0  Duque convoca coalición mundial para proteger ...
# 1  Las economías no pueden seguir dependiendo de ...
#
#                                            summaries authors  \
# 0  En su intervención en la Cumbre sobre Bosques ...     ...
# 1  Estudios realizados por analistas de 14 países...     ...
#
#                       dates  \
# 0  23 de septiembre de 2019
# 1  30 de septiembre de 2019
#
#                                           paragraphs  \
# 0  Durante su intervención en la Cumbre sobre los...
# 1  Los modelos actuales de producción deben repla...
#
#                                               themes
# 0  Juventud se manifiesta en cumbre por el clima,...
# 1  Extracción de recursos naturales, Cambio climá...
# None
# None
# None
#                                               titles  \
# 0  Duque convoca coalición mundial para proteger ...
# 1  Las economías no pueden seguir dependiendo de ...
# 2  Fuertes vientos continuarán este jueves y vier...
#
#                                            summaries authors  \
# 0  En su intervención en la Cumbre sobre Bosques ...     ...
# 1  Estudios realizados por analistas de 14 países...     ...
# 2  La transición entre la temporada de lluvias y ...     ...
#
#                       dates  \
# 0  23 de septiembre de 2019
# 1  30 de septiembre de 2019
# 2       27 de junio de 2019
#
#                                           paragraphs  \
# 0  Durante su intervención en la Cumbre sobre los...
# 1  Los modelos actuales de producción deben repla...
# 2  Ráfagas de vientos que alcanzan los 30 y hasta...
#
#                                               themes
# 0  Juventud se manifiesta en cumbre por el clima,...
# 1  Extracción de recursos naturales, Cambio climá...
# 2  Transición entre temporada de lluvias y seca, ...
# None
# None
# None
#                                               titles  \
# 0  Duque convoca coalición mundial para proteger ...
# 1  Las economías no pueden seguir dependiendo de ...
# 2  Fuertes vientos continuarán este jueves y vier...
# 3  El conflicto del hombre con la fauna silvestre...
#
#                                            summaries authors  \
# 0  En su intervención en la Cumbre sobre Bosques ...     ...
# 1  Estudios realizados por analistas de 14 países...     ...
# 2  La transición entre la temporada de lluvias y ...     ...
# 3  Un informe de WWF y el Programa de Naciones Un...     ...
#
#                       dates  \
# 0  23 de septiembre de 2019
# 1  30 de septiembre de 2019
# 2       27 de junio de 2019
# 3        8 de julio de 2021
#
#                                           paragraphs  \
# 0  Durante su intervención en la Cumbre sobre los...
# 1  Los modelos actuales de producción deben repla...
# 2  Ráfagas de vientos que alcanzan los 30 y hasta...
# 3  El conflicto entre los seres humanos y la vida...
#
#                                               themes
# 0  Juventud se manifiesta en cumbre por el clima,...
# 1  Extracción de recursos naturales, Cambio climá...
# 2  Transición entre temporada de lluvias y seca, ...
# 3  Fauna silvestre, Especies en peligro, Especies...
# None
# None
# None
#                                               titles  \
# 0  Duque convoca coalición mundial para proteger ...
# 1  Las economías no pueden seguir dependiendo de ...
# 2  Fuertes vientos continuarán este jueves y vier...
# 3  El conflicto del hombre con la fauna silvestre...
# 4  ¿Qué es el Observatorio Ambiental de Bogotá y ...
#
#                                            summaries authors  \
# 0  En su intervención en la Cumbre sobre Bosques ...     ...
# 1  Estudios realizados por analistas de 14 países...     ...
# 2  La transición entre la temporada de lluvias y ...     ...
# 3  Un informe de WWF y el Programa de Naciones Un...     ...
# 4  Esta herramienta de la Secretaría Distrital de...     ...
#
#                       dates  \
# 0  23 de septiembre de 2019
# 1  30 de septiembre de 2019
# 2       27 de junio de 2019
# 3        8 de julio de 2021
# 4       24 de junio de 2021
#
#                                           paragraphs  \
# 0  Durante su intervención en la Cumbre sobre los...
# 1  Los modelos actuales de producción deben repla...
# 2  Ráfagas de vientos que alcanzan los 30 y hasta...
# 3  El conflicto entre los seres humanos y la vida...
# 4  La pedagogía es una herramienta clave para cre...
#
#                                               themes
# 0  Juventud se manifiesta en cumbre por el clima,...
# 1  Extracción de recursos naturales, Cambio climá...
# 2  Transición entre temporada de lluvias y seca, ...
# 3  Fauna silvestre, Especies en peligro, Especies...
# 4  Grupo río Bogotá, Río Bogotá, Cuenca del Río B...
# None
# None
# None
#                                               titles  \
# 0  Duque convoca coalición mundial para proteger ...
# 1  Las economías no pueden seguir dependiendo de ...
# 2  Fuertes vientos continuarán este jueves y vier...
# 3  El conflicto del hombre con la fauna silvestre...
# 4  ¿Qué es el Observatorio Ambiental de Bogotá y ...
# 5  Cosquillas en el nido, el libro que enseña tod...
#
#                                            summaries authors  \
# 0  En su intervención en la Cumbre sobre Bosques ...     ...
# 1  Estudios realizados por analistas de 14 países...     ...
# 2  La transición entre la temporada de lluvias y ...     ...
# 3  Un informe de WWF y el Programa de Naciones Un...     ...
# 4  Esta herramienta de la Secretaría Distrital de...     ...
# 5  Tendrá una versión impresa y otra transmedia p...     ...
#
#                       dates  \
# 0  23 de septiembre de 2019
# 1  30 de septiembre de 2019
# 2       27 de junio de 2019
# 3        8 de julio de 2021
# 4       24 de junio de 2021
# 5        9 de junio de 2021
#
#                                           paragraphs  \
# 0  Durante su intervención en la Cumbre sobre los...
# 1  Los modelos actuales de producción deben repla...
# 2  Ráfagas de vientos que alcanzan los 30 y hasta...
# 3  El conflicto entre los seres humanos y la vida...
# 4  La pedagogía es una herramienta clave para cre...
# 5  Con más de 540 especies de animales, la cuenca...
#
#                                               themes
# 0  Juventud se manifiesta en cumbre por el clima,...
# 1  Extracción de recursos naturales, Cambio climá...
# 2  Transición entre temporada de lluvias y seca, ...
# 3  Fauna silvestre, Especies en peligro, Especies...
# 4  Grupo río Bogotá, Río Bogotá, Cuenca del Río B...
# 5  Grupo río Bogotá, Humedales de Bogotá, Río Bog...
# None
# None
# None
#                                               titles  \
# 0  Duque convoca coalición mundial para proteger ...
# 1  Las economías no pueden seguir dependiendo de ...
# 2  Fuertes vientos continuarán este jueves y vier...
# 3  El conflicto del hombre con la fauna silvestre...
# 4  ¿Qué es el Observatorio Ambiental de Bogotá y ...
# 5  Cosquillas en el nido, el libro que enseña tod...
# 6  La generación de energía también puede salvar ...
#
#                                            summaries authors  \
# 0  En su intervención en la Cumbre sobre Bosques ...     ...
# 1  Estudios realizados por analistas de 14 países...     ...
# 2  La transición entre la temporada de lluvias y ...     ...
# 3  Un informe de WWF y el Programa de Naciones Un...     ...
# 4  Esta herramienta de la Secretaría Distrital de...     ...
# 5  Tendrá una versión impresa y otra transmedia p...     ...
# 6  Con el lanzamiento de Enel Biodiversa, este gr...     ...
#
#                       dates  \
# 0  23 de septiembre de 2019
# 1  30 de septiembre de 2019
# 2       27 de junio de 2019
# 3        8 de julio de 2021
# 4       24 de junio de 2021
# 5        9 de junio de 2021
# 6        28 de mayo de 2021
#
#                                           paragraphs  \
# 0  Durante su intervención en la Cumbre sobre los...
# 1  Los modelos actuales de producción deben repla...
# 2  Ráfagas de vientos que alcanzan los 30 y hasta...
# 3  El conflicto entre los seres humanos y la vida...
# 4  La pedagogía es una herramienta clave para cre...
# 5  Con más de 540 especies de animales, la cuenca...
# 6  Las apuestas del sector empresarial por trabaj...
#
#                                               themes
# 0  Juventud se manifiesta en cumbre por el clima,...
# 1  Extracción de recursos naturales, Cambio climá...
# 2  Transición entre temporada de lluvias y seca, ...
# 3  Fauna silvestre, Especies en peligro, Especies...
# 4  Grupo río Bogotá, Río Bogotá, Cuenca del Río B...
# 5  Grupo río Bogotá, Humedales de Bogotá, Río Bog...
# 6      Energía, Ecosistema, Biodiversidad, bosques,
# None
# None
# None
#                                               titles  \
# 0  Duque convoca coalición mundial para proteger ...
# 1  Las economías no pueden seguir dependiendo de ...
# 2  Fuertes vientos continuarán este jueves y vier...
# 3  El conflicto del hombre con la fauna silvestre...
# 4  ¿Qué es el Observatorio Ambiental de Bogotá y ...
# 5  Cosquillas en el nido, el libro que enseña tod...
# 6  La generación de energía también puede salvar ...
# 7            Osos polares se extinguirían en 80 años
#
#                                            summaries authors  \
# 0  En su intervención en la Cumbre sobre Bosques ...     ...
# 1  Estudios realizados por analistas de 14 países...     ...
# 2  La transición entre la temporada de lluvias y ...     ...
# 3  Un informe de WWF y el Programa de Naciones Un...     ...
# 4  Esta herramienta de la Secretaría Distrital de...     ...
# 5  Tendrá una versión impresa y otra transmedia p...     ...
# 6  Con el lanzamiento de Enel Biodiversa, este gr...     ...
# 7  Un estudio adelantado por la organización Osos...     ...
#
#                       dates  \
# 0  23 de septiembre de 2019
# 1  30 de septiembre de 2019
# 2       27 de junio de 2019
# 3        8 de julio de 2021
# 4       24 de junio de 2021
# 5        9 de junio de 2021
# 6        28 de mayo de 2021
# 7  21 de septiembre de 2020
#
#                                           paragraphs  \
# 0  Durante su intervención en la Cumbre sobre los...
# 1  Los modelos actuales de producción deben repla...
# 2  Ráfagas de vientos que alcanzan los 30 y hasta...
# 3  El conflicto entre los seres humanos y la vida...
# 4  La pedagogía es una herramienta clave para cre...
# 5  Con más de 540 especies de animales, la cuenca...
# 6  Las apuestas del sector empresarial por trabaj...
# 7  En el mundo solo sobreviven cerca de 26.000 ej...
#
#                                               themes
# 0  Juventud se manifiesta en cumbre por el clima,...
# 1  Extracción de recursos naturales, Cambio climá...
# 2  Transición entre temporada de lluvias y seca, ...
# 3  Fauna silvestre, Especies en peligro, Especies...
# 4  Grupo río Bogotá, Río Bogotá, Cuenca del Río B...
# 5  Grupo río Bogotá, Humedales de Bogotá, Río Bog...
# 6      Energía, Ecosistema, Biodiversidad, bosques,
# 7  Extinción de osos polares, Osos polares, Osos ...
# None
# None
# None
#                                               titles  \
# 0  Duque convoca coalición mundial para proteger ...
# 1  Las economías no pueden seguir dependiendo de ...
# 2  Fuertes vientos continuarán este jueves y vier...
# 3  El conflicto del hombre con la fauna silvestre...
# 4  ¿Qué es el Observatorio Ambiental de Bogotá y ...
# 5  Cosquillas en el nido, el libro que enseña tod...
# 6  La generación de energía también puede salvar ...
# 7            Osos polares se extinguirían en 80 años
# 8  "Nuestra supervivencia depende del estado de l...
#
#                                            summaries authors  \
# 0  En su intervención en la Cumbre sobre Bosques ...     ...
# 1  Estudios realizados por analistas de 14 países...     ...
# 2  La transición entre la temporada de lluvias y ...     ...
# 3  Un informe de WWF y el Programa de Naciones Un...     ...
# 4  Esta herramienta de la Secretaría Distrital de...     ...
# 5  Tendrá una versión impresa y otra transmedia p...     ...
# 6  Con el lanzamiento de Enel Biodiversa, este gr...     ...
# 7  Un estudio adelantado por la organización Osos...     ...
# 8  La presidenta de la Plataforma Intergubernamen...     ...
#
#                       dates  \
# 0  23 de septiembre de 2019
# 1  30 de septiembre de 2019
# 2       27 de junio de 2019
# 3        8 de julio de 2021
# 4       24 de junio de 2021
# 5        9 de junio de 2021
# 6        28 de mayo de 2021
# 7  21 de septiembre de 2020
# 8  11 de septiembre de 2020
#
#                                           paragraphs  \
# 0  Durante su intervención en la Cumbre sobre los...
# 1  Los modelos actuales de producción deben repla...
# 2  Ráfagas de vientos que alcanzan los 30 y hasta...
# 3  El conflicto entre los seres humanos y la vida...
# 4  La pedagogía es una herramienta clave para cre...
# 5  Con más de 540 especies de animales, la cuenca...
# 6  Las apuestas del sector empresarial por trabaj...
# 7  En el mundo solo sobreviven cerca de 26.000 ej...
# 8  Ana María Hernández sueña con un país en térmi...
#
#                                               themes
# 0  Juventud se manifiesta en cumbre por el clima,...
# 1  Extracción de recursos naturales, Cambio climá...
# 2  Transición entre temporada de lluvias y seca, ...
# 3  Fauna silvestre, Especies en peligro, Especies...
# 4  Grupo río Bogotá, Río Bogotá, Cuenca del Río B...
# 5  Grupo río Bogotá, Humedales de Bogotá, Río Bog...
# 6      Energía, Ecosistema, Biodiversidad, bosques,
# 7  Extinción de osos polares, Osos polares, Osos ...
# 8  Día Nacional de la Biodiversidad, Ana María He...
# None
# None
# None
#                                               titles  \
# 0  Duque convoca coalición mundial para proteger ...
# 1  Las economías no pueden seguir dependiendo de ...
# 2  Fuertes vientos continuarán este jueves y vier...
# 3  El conflicto del hombre con la fauna silvestre...
# 4  ¿Qué es el Observatorio Ambiental de Bogotá y ...
# 5  Cosquillas en el nido, el libro que enseña tod...
# 6  La generación de energía también puede salvar ...
# 7            Osos polares se extinguirían en 80 años
# 8  "Nuestra supervivencia depende del estado de l...
# 9  Sea un ciudadano más amigable con el medio amb...
#
#                                            summaries authors  \
# 0  En su intervención en la Cumbre sobre Bosques ...     ...
# 1  Estudios realizados por analistas de 14 países...     ...
# 2  La transición entre la temporada de lluvias y ...     ...
# 3  Un informe de WWF y el Programa de Naciones Un...     ...
# 4  Esta herramienta de la Secretaría Distrital de...     ...
# 5  Tendrá una versión impresa y otra transmedia p...     ...
# 6  Con el lanzamiento de Enel Biodiversa, este gr...     ...
# 7  Un estudio adelantado por la organización Osos...     ...
# 8  La presidenta de la Plataforma Intergubernamen...     ...
# 9  El mundo requiere acciones urgentes para mitig...     ...
#
#                       dates  \
# 0  23 de septiembre de 2019
# 1  30 de septiembre de 2019
# 2       27 de junio de 2019
# 3        8 de julio de 2021
# 4       24 de junio de 2021
# 5        9 de junio de 2021
# 6        28 de mayo de 2021
# 7  21 de septiembre de 2020
# 8  11 de septiembre de 2020
# 9   31 de diciembre de 2019
#
#                                           paragraphs  \
# 0  Durante su intervención en la Cumbre sobre los...
# 1  Los modelos actuales de producción deben repla...
# 2  Ráfagas de vientos que alcanzan los 30 y hasta...
# 3  El conflicto entre los seres humanos y la vida...
# 4  La pedagogía es una herramienta clave para cre...
# 5  Con más de 540 especies de animales, la cuenca...
# 6  Las apuestas del sector empresarial por trabaj...
# 7  En el mundo solo sobreviven cerca de 26.000 ej...
# 8  Ana María Hernández sueña con un país en térmi...
# 9  A los humanos se le acaba el plazo para evitar...
#
#                                               themes
# 0  Juventud se manifiesta en cumbre por el clima,...
# 1  Extracción de recursos naturales, Cambio climá...
# 2  Transición entre temporada de lluvias y seca, ...
# 3  Fauna silvestre, Especies en peligro, Especies...
# 4  Grupo río Bogotá, Río Bogotá, Cuenca del Río B...
# 5  Grupo río Bogotá, Humedales de Bogotá, Río Bog...
# 6      Energía, Ecosistema, Biodiversidad, bosques,
# 7  Extinción de osos polares, Osos polares, Osos ...
# 8  Día Nacional de la Biodiversidad, Ana María He...
# 9  Reciclaje, Calentamiento global, Contaminación...
# None
# None
# None
# None
#                                                titles  \
# 0   Duque convoca coalición mundial para proteger ...
# 1   Las economías no pueden seguir dependiendo de ...
# 2   Fuertes vientos continuarán este jueves y vier...
# 3   El conflicto del hombre con la fauna silvestre...
# 4   ¿Qué es el Observatorio Ambiental de Bogotá y ...
# 5   Cosquillas en el nido, el libro que enseña tod...
# 6   La generación de energía también puede salvar ...
# 7             Osos polares se extinguirían en 80 años
# 8   "Nuestra supervivencia depende del estado de l...
# 9   Sea un ciudadano más amigable con el medio amb...
# 10  Los pingüinos emperador podrían desaparecer pa...
#
#                                             summaries         authors  \
# 0   En su intervención en la Cumbre sobre Bosques ...             ...
# 1   Estudios realizados por analistas de 14 países...             ...
# 2   La transición entre la temporada de lluvias y ...             ...
# 3   Un informe de WWF y el Programa de Naciones Un...             ...
# 4   Esta herramienta de la Secretaría Distrital de...             ...
# 5   Tendrá una versión impresa y otra transmedia p...             ...
# 6   Con el lanzamiento de Enel Biodiversa, este gr...             ...
# 7   Un estudio adelantado por la organización Osos...             ...
# 8   La presidenta de la Plataforma Intergubernamen...             ...
# 9   El mundo requiere acciones urgentes para mitig...             ...
# 10  Investigadores combinaron un modelo climático ...  Mongabay Latam
#
#                        dates  \
# 0   23 de septiembre de 2019
# 1   30 de septiembre de 2019
# 2        27 de junio de 2019
# 3         8 de julio de 2021
# 4        24 de junio de 2021
# 5         9 de junio de 2021
# 6         28 de mayo de 2021
# 7   21 de septiembre de 2020
# 8   11 de septiembre de 2020
# 9    31 de diciembre de 2019
# 10        8 de enero de 2020
#
#                                            paragraphs  \
# 0   Durante su intervención en la Cumbre sobre los...
# 1   Los modelos actuales de producción deben repla...
# 2   Ráfagas de vientos que alcanzan los 30 y hasta...
# 3   El conflicto entre los seres humanos y la vida...
# 4   La pedagogía es una herramienta clave para cre...
# 5   Con más de 540 especies de animales, la cuenca...
# 6   Las apuestas del sector empresarial por trabaj...
# 7   En el mundo solo sobreviven cerca de 26.000 ej...
# 8   Ana María Hernández sueña con un país en térmi...
# 9   A los humanos se le acaba el plazo para evitar...
# 10  Si el clima continúa cambiando a su ritmo actu...
#
#                                                themes
# 0   Juventud se manifiesta en cumbre por el clima,...
# 1   Extracción de recursos naturales, Cambio climá...
# 2   Transición entre temporada de lluvias y seca, ...
# 3   Fauna silvestre, Especies en peligro, Especies...
# 4   Grupo río Bogotá, Río Bogotá, Cuenca del Río B...
# 5   Grupo río Bogotá, Humedales de Bogotá, Río Bog...
# 6       Energía, Ecosistema, Biodiversidad, bosques,
# 7   Extinción de osos polares, Osos polares, Osos ...
# 8   Día Nacional de la Biodiversidad, Ana María He...
# 9   Reciclaje, Calentamiento global, Contaminación...
# 10  Pingüinos emperador, Científicos y animales en...
# None
# None
# None
#                                                titles  \
# 0   Duque convoca coalición mundial para proteger ...
# 1   Las economías no pueden seguir dependiendo de ...
# 2   Fuertes vientos continuarán este jueves y vier...
# 3   El conflicto del hombre con la fauna silvestre...
# 4   ¿Qué es el Observatorio Ambiental de Bogotá y ...
# 5   Cosquillas en el nido, el libro que enseña tod...
# 6   La generación de energía también puede salvar ...
# 7             Osos polares se extinguirían en 80 años
# 8   "Nuestra supervivencia depende del estado de l...
# 9   Sea un ciudadano más amigable con el medio amb...
# 10  Los pingüinos emperador podrían desaparecer pa...
# 11  Huelga mundial por el clima exigirá acciones r...
#
#                                             summaries         authors  \
# 0   En su intervención en la Cumbre sobre Bosques ...             ...
# 1   Estudios realizados por analistas de 14 países...             ...
# 2   La transición entre la temporada de lluvias y ...             ...
# 3   Un informe de WWF y el Programa de Naciones Un...             ...
# 4   Esta herramienta de la Secretaría Distrital de...             ...
# 5   Tendrá una versión impresa y otra transmedia p...             ...
# 6   Con el lanzamiento de Enel Biodiversa, este gr...             ...
# 7   Un estudio adelantado por la organización Osos...             ...
# 8   La presidenta de la Plataforma Intergubernamen...             ...
# 9   El mundo requiere acciones urgentes para mitig...             ...
# 10  Investigadores combinaron un modelo climático ...  Mongabay Latam
# 11  Liderada por Greta Thunberg se realizará este ...             ...
#
#                        dates  \
# 0   23 de septiembre de 2019
# 1   30 de septiembre de 2019
# 2        27 de junio de 2019
# 3         8 de julio de 2021
# 4        24 de junio de 2021
# 5         9 de junio de 2021
# 6         28 de mayo de 2021
# 7   21 de septiembre de 2020
# 8   11 de septiembre de 2020
# 9    31 de diciembre de 2019
# 10        8 de enero de 2020
# 11    6 de diciembre de 2019
#
#                                            paragraphs  \
# 0   Durante su intervención en la Cumbre sobre los...
# 1   Los modelos actuales de producción deben repla...
# 2   Ráfagas de vientos que alcanzan los 30 y hasta...
# 3   El conflicto entre los seres humanos y la vida...
# 4   La pedagogía es una herramienta clave para cre...
# 5   Con más de 540 especies de animales, la cuenca...
# 6   Las apuestas del sector empresarial por trabaj...
# 7   En el mundo solo sobreviven cerca de 26.000 ej...
# 8   Ana María Hernández sueña con un país en térmi...
# 9   A los humanos se le acaba el plazo para evitar...
# 10  Si el clima continúa cambiando a su ritmo actu...
# 11  Cuatro millones de personas se espera que part...
#
#                                                themes
# 0   Juventud se manifiesta en cumbre por el clima,...
# 1   Extracción de recursos naturales, Cambio climá...
# 2   Transición entre temporada de lluvias y seca, ...
# 3   Fauna silvestre, Especies en peligro, Especies...
# 4   Grupo río Bogotá, Río Bogotá, Cuenca del Río B...
# 5   Grupo río Bogotá, Humedales de Bogotá, Río Bog...
# 6       Energía, Ecosistema, Biodiversidad, bosques,
# 7   Extinción de osos polares, Osos polares, Osos ...
# 8   Día Nacional de la Biodiversidad, Ana María He...
# 9   Reciclaje, Calentamiento global, Contaminación...
# 10  Pingüinos emperador, Científicos y animales en...
# 11  Greta Thunberg, Huelga mundial por el clima, C...
# None
# None
# None
#                                                titles  \
# 0   Duque convoca coalición mundial para proteger ...
# 1   Las economías no pueden seguir dependiendo de ...
# 2   Fuertes vientos continuarán este jueves y vier...
# 3   El conflicto del hombre con la fauna silvestre...
# 4   ¿Qué es el Observatorio Ambiental de Bogotá y ...
# 5   Cosquillas en el nido, el libro que enseña tod...
# 6   La generación de energía también puede salvar ...
# 7             Osos polares se extinguirían en 80 años
# 8   "Nuestra supervivencia depende del estado de l...
# 9   Sea un ciudadano más amigable con el medio amb...
# 10  Los pingüinos emperador podrían desaparecer pa...
# 11  Huelga mundial por el clima exigirá acciones r...
# 12  Más de 50 osos polares acechan una aldea en bu...
#
#                                             summaries         authors  \
# 0   En su intervención en la Cumbre sobre Bosques ...             ...
# 1   Estudios realizados por analistas de 14 países...             ...
# 2   La transición entre la temporada de lluvias y ...             ...
# 3   Un informe de WWF y el Programa de Naciones Un...             ...
# 4   Esta herramienta de la Secretaría Distrital de...             ...
# 5   Tendrá una versión impresa y otra transmedia p...             ...
# 6   Con el lanzamiento de Enel Biodiversa, este gr...             ...
# 7   Un estudio adelantado por la organización Osos...             ...
# 8   La presidenta de la Plataforma Intergubernamen...             ...
# 9   El mundo requiere acciones urgentes para mitig...             ...
# 10  Investigadores combinaron un modelo climático ...  Mongabay Latam
# 11  Liderada por Greta Thunberg se realizará este ...             ...
# 12  Los animales hambrientos y flacos generaron zo...             ...
#
#                        dates  \
# 0   23 de septiembre de 2019
# 1   30 de septiembre de 2019
# 2        27 de junio de 2019
# 3         8 de julio de 2021
# 4        24 de junio de 2021
# 5         9 de junio de 2021
# 6         28 de mayo de 2021
# 7   21 de septiembre de 2020
# 8   11 de septiembre de 2020
# 9    31 de diciembre de 2019
# 10        8 de enero de 2020
# 11    6 de diciembre de 2019
# 12    6 de diciembre de 2019
#
#                                            paragraphs  \
# 0   Durante su intervención en la Cumbre sobre los...
# 1   Los modelos actuales de producción deben repla...
# 2   Ráfagas de vientos que alcanzan los 30 y hasta...
# 3   El conflicto entre los seres humanos y la vida...
# 4   La pedagogía es una herramienta clave para cre...
# 5   Con más de 540 especies de animales, la cuenca...
# 6   Las apuestas del sector empresarial por trabaj...
# 7   En el mundo solo sobreviven cerca de 26.000 ej...
# 8   Ana María Hernández sueña con un país en térmi...
# 9   A los humanos se le acaba el plazo para evitar...
# 10  Si el clima continúa cambiando a su ritmo actu...
# 11  Cuatro millones de personas se espera que part...
# 12  Un pequeño poblado en el Ártico de Rusia vive ...
#
#                                                themes
# 0   Juventud se manifiesta en cumbre por el clima,...
# 1   Extracción de recursos naturales, Cambio climá...
# 2   Transición entre temporada de lluvias y seca, ...
# 3   Fauna silvestre, Especies en peligro, Especies...
# 4   Grupo río Bogotá, Río Bogotá, Cuenca del Río B...
# 5   Grupo río Bogotá, Humedales de Bogotá, Río Bog...
# 6       Energía, Ecosistema, Biodiversidad, bosques,
# 7   Extinción de osos polares, Osos polares, Osos ...
# 8   Día Nacional de la Biodiversidad, Ana María He...
# 9   Reciclaje, Calentamiento global, Contaminación...
# 10  Pingüinos emperador, Científicos y animales en...
# 11  Greta Thunberg, Huelga mundial por el clima, C...
# 12  Osos polares, Osos polares afectados por el ca...
# None
# None
# None
#                                                titles  \
# 0   Duque convoca coalición mundial para proteger ...
# 1   Las economías no pueden seguir dependiendo de ...
# 2   Fuertes vientos continuarán este jueves y vier...
# 3   El conflicto del hombre con la fauna silvestre...
# 4   ¿Qué es el Observatorio Ambiental de Bogotá y ...
# 5   Cosquillas en el nido, el libro que enseña tod...
# 6   La generación de energía también puede salvar ...
# 7             Osos polares se extinguirían en 80 años
# 8   "Nuestra supervivencia depende del estado de l...
# 9   Sea un ciudadano más amigable con el medio amb...
# 10  Los pingüinos emperador podrían desaparecer pa...
# 11  Huelga mundial por el clima exigirá acciones r...
# 12  Más de 50 osos polares acechan una aldea en bu...
# 13  Greta Thunberg recibió el premio como embajado...
#
#                                             summaries         authors  \
# 0   En su intervención en la Cumbre sobre Bosques ...             ...
# 1   Estudios realizados por analistas de 14 países...             ...
# 2   La transición entre la temporada de lluvias y ...             ...
# 3   Un informe de WWF y el Programa de Naciones Un...             ...
# 4   Esta herramienta de la Secretaría Distrital de...             ...
# 5   Tendrá una versión impresa y otra transmedia p...             ...
# 6   Con el lanzamiento de Enel Biodiversa, este gr...             ...
# 7   Un estudio adelantado por la organización Osos...             ...
# 8   La presidenta de la Plataforma Intergubernamen...             ...
# 9   El mundo requiere acciones urgentes para mitig...             ...
# 10  Investigadores combinaron un modelo climático ...  Mongabay Latam
# 11  Liderada por Greta Thunberg se realizará este ...             ...
# 12  Los animales hambrientos y flacos generaron zo...             ...
# 13  La activista sueca, de 16 años, obtuvo el gala...             ...
#
#                        dates  \
# 0   23 de septiembre de 2019
# 1   30 de septiembre de 2019
# 2        27 de junio de 2019
# 3         8 de julio de 2021
# 4        24 de junio de 2021
# 5         9 de junio de 2021
# 6         28 de mayo de 2021
# 7   21 de septiembre de 2020
# 8   11 de septiembre de 2020
# 9    31 de diciembre de 2019
# 10        8 de enero de 2020
# 11    6 de diciembre de 2019
# 12    6 de diciembre de 2019
# 13       22 de julio de 2019
#
#                                            paragraphs  \
# 0   Durante su intervención en la Cumbre sobre los...
# 1   Los modelos actuales de producción deben repla...
# 2   Ráfagas de vientos que alcanzan los 30 y hasta...
# 3   El conflicto entre los seres humanos y la vida...
# 4   La pedagogía es una herramienta clave para cre...
# 5   Con más de 540 especies de animales, la cuenca...
# 6   Las apuestas del sector empresarial por trabaj...
# 7   En el mundo solo sobreviven cerca de 26.000 ej...
# 8   Ana María Hernández sueña con un país en térmi...
# 9   A los humanos se le acaba el plazo para evitar...
# 10  Si el clima continúa cambiando a su ritmo actu...
# 11  Cuatro millones de personas se espera que part...
# 12  Un pequeño poblado en el Ártico de Rusia vive ...
# 13  La organización de defensa de los derechos hum...
#
#                                                themes
# 0   Juventud se manifiesta en cumbre por el clima,...
# 1   Extracción de recursos naturales, Cambio climá...
# 2   Transición entre temporada de lluvias y seca, ...
# 3   Fauna silvestre, Especies en peligro, Especies...
# 4   Grupo río Bogotá, Río Bogotá, Cuenca del Río B...
# 5   Grupo río Bogotá, Humedales de Bogotá, Río Bog...
# 6       Energía, Ecosistema, Biodiversidad, bosques,
# 7   Extinción de osos polares, Osos polares, Osos ...
# 8   Día Nacional de la Biodiversidad, Ana María He...
# 9   Reciclaje, Calentamiento global, Contaminación...
# 10  Pingüinos emperador, Científicos y animales en...
# 11  Greta Thunberg, Huelga mundial por el clima, C...
# 12  Osos polares, Osos polares afectados por el ca...
# 13  Greta Thunberg y cambio climático, Amnistía In...
# None
# None
# None
#                                                titles  \
# 0   Duque convoca coalición mundial para proteger ...
# 1   Las economías no pueden seguir dependiendo de ...
# 2   Fuertes vientos continuarán este jueves y vier...
# 3   El conflicto del hombre con la fauna silvestre...
# 4   ¿Qué es el Observatorio Ambiental de Bogotá y ...
# 5   Cosquillas en el nido, el libro que enseña tod...
# 6   La generación de energía también puede salvar ...
# 7             Osos polares se extinguirían en 80 años
# 8   "Nuestra supervivencia depende del estado de l...
# 9   Sea un ciudadano más amigable con el medio amb...
# 10  Los pingüinos emperador podrían desaparecer pa...
# 11  Huelga mundial por el clima exigirá acciones r...
# 12  Más de 50 osos polares acechan una aldea en bu...
# 13  Greta Thunberg recibió el premio como embajado...
# 14  Greta Thunberg viajará a América en velero par...
#
#                                             summaries         authors  \
# 0   En su intervención en la Cumbre sobre Bosques ...             ...
# 1   Estudios realizados por analistas de 14 países...             ...
# 2   La transición entre la temporada de lluvias y ...             ...
# 3   Un informe de WWF y el Programa de Naciones Un...             ...
# 4   Esta herramienta de la Secretaría Distrital de...             ...
# 5   Tendrá una versión impresa y otra transmedia p...             ...
# 6   Con el lanzamiento de Enel Biodiversa, este gr...             ...
# 7   Un estudio adelantado por la organización Osos...             ...
# 8   La presidenta de la Plataforma Intergubernamen...             ...
# 9   El mundo requiere acciones urgentes para mitig...             ...
# 10  Investigadores combinaron un modelo climático ...  Mongabay Latam
# 11  Liderada por Greta Thunberg se realizará este ...             ...
# 12  Los animales hambrientos y flacos generaron zo...             ...
# 13  La activista sueca, de 16 años, obtuvo el gala...             ...
# 14  El Malizia II es un yate de alta velocidad que...             ...
#
#                        dates  \
# 0   23 de septiembre de 2019
# 1   30 de septiembre de 2019
# 2        27 de junio de 2019
# 3         8 de julio de 2021
# 4        24 de junio de 2021
# 5         9 de junio de 2021
# 6         28 de mayo de 2021
# 7   21 de septiembre de 2020
# 8   11 de septiembre de 2020
# 9    31 de diciembre de 2019
# 10        8 de enero de 2020
# 11    6 de diciembre de 2019
# 12    6 de diciembre de 2019
# 13       22 de julio de 2019
# 14       30 de julio de 2019
#
#                                            paragraphs  \
# 0   Durante su intervención en la Cumbre sobre los...
# 1   Los modelos actuales de producción deben repla...
# 2   Ráfagas de vientos que alcanzan los 30 y hasta...
# 3   El conflicto entre los seres humanos y la vida...
# 4   La pedagogía es una herramienta clave para cre...
# 5   Con más de 540 especies de animales, la cuenca...
# 6   Las apuestas del sector empresarial por trabaj...
# 7   En el mundo solo sobreviven cerca de 26.000 ej...
# 8   Ana María Hernández sueña con un país en térmi...
# 9   A los humanos se le acaba el plazo para evitar...
# 10  Si el clima continúa cambiando a su ritmo actu...
# 11  Cuatro millones de personas se espera que part...
# 12  Un pequeño poblado en el Ártico de Rusia vive ...
# 13  La organización de defensa de los derechos hum...
# 14  La joven activista ambiental sueca Greta Thunb...
#
#                                                themes
# 0   Juventud se manifiesta en cumbre por el clima,...
# 1   Extracción de recursos naturales, Cambio climá...
# 2   Transición entre temporada de lluvias y seca, ...
# 3   Fauna silvestre, Especies en peligro, Especies...
# 4   Grupo río Bogotá, Río Bogotá, Cuenca del Río B...
# 5   Grupo río Bogotá, Humedales de Bogotá, Río Bog...
# 6       Energía, Ecosistema, Biodiversidad, bosques,
# 7   Extinción de osos polares, Osos polares, Osos ...
# 8   Día Nacional de la Biodiversidad, Ana María He...
# 9   Reciclaje, Calentamiento global, Contaminación...
# 10  Pingüinos emperador, Científicos y animales en...
# 11  Greta Thunberg, Huelga mundial por el clima, C...
# 12  Osos polares, Osos polares afectados por el ca...
# 13  Greta Thunberg y cambio climático, Amnistía In...
# 14  Greta Thunberg viajará a América, Greta Thunbe...
# None
# None
# None
#                                                titles  \
# 0   Duque convoca coalición mundial para proteger ...
# 1   Las economías no pueden seguir dependiendo de ...
# 2   Fuertes vientos continuarán este jueves y vier...
# 3   El conflicto del hombre con la fauna silvestre...
# 4   ¿Qué es el Observatorio Ambiental de Bogotá y ...
# 5   Cosquillas en el nido, el libro que enseña tod...
# 6   La generación de energía también puede salvar ...
# 7             Osos polares se extinguirían en 80 años
# 8   "Nuestra supervivencia depende del estado de l...
# 9   Sea un ciudadano más amigable con el medio amb...
# 10  Los pingüinos emperador podrían desaparecer pa...
# 11  Huelga mundial por el clima exigirá acciones r...
# 12  Más de 50 osos polares acechan una aldea en bu...
# 13  Greta Thunberg recibió el premio como embajado...
# 14  Greta Thunberg viajará a América en velero par...
# 15               Australia no tendrá invierno en 2050
#
#                                             summaries         authors  \
# 0   En su intervención en la Cumbre sobre Bosques ...             ...
# 1   Estudios realizados por analistas de 14 países...             ...
# 2   La transición entre la temporada de lluvias y ...             ...
# 3   Un informe de WWF y el Programa de Naciones Un...             ...
# 4   Esta herramienta de la Secretaría Distrital de...             ...
# 5   Tendrá una versión impresa y otra transmedia p...             ...
# 6   Con el lanzamiento de Enel Biodiversa, este gr...             ...
# 7   Un estudio adelantado por la organización Osos...             ...
# 8   La presidenta de la Plataforma Intergubernamen...             ...
# 9   El mundo requiere acciones urgentes para mitig...             ...
# 10  Investigadores combinaron un modelo climático ...  Mongabay Latam
# 11  Liderada por Greta Thunberg se realizará este ...             ...
# 12  Los animales hambrientos y flacos generaron zo...             ...
# 13  La activista sueca, de 16 años, obtuvo el gala...             ...
# 14  El Malizia II es un yate de alta velocidad que...             ...
# 15  Una nueva herramienta climática indica que en ...             ...
#
#                        dates  \
# 0   23 de septiembre de 2019
# 1   30 de septiembre de 2019
# 2        27 de junio de 2019
# 3         8 de julio de 2021
# 4        24 de junio de 2021
# 5         9 de junio de 2021
# 6         28 de mayo de 2021
# 7   21 de septiembre de 2020
# 8   11 de septiembre de 2020
# 9    31 de diciembre de 2019
# 10        8 de enero de 2020
# 11    6 de diciembre de 2019
# 12    6 de diciembre de 2019
# 13       22 de julio de 2019
# 14       30 de julio de 2019
# 15       13 de marzo de 2019
#
#                                            paragraphs  \
# 0   Durante su intervención en la Cumbre sobre los...
# 1   Los modelos actuales de producción deben repla...
# 2   Ráfagas de vientos que alcanzan los 30 y hasta...
# 3   El conflicto entre los seres humanos y la vida...
# 4   La pedagogía es una herramienta clave para cre...
# 5   Con más de 540 especies de animales, la cuenca...
# 6   Las apuestas del sector empresarial por trabaj...
# 7   En el mundo solo sobreviven cerca de 26.000 ej...
# 8   Ana María Hernández sueña con un país en térmi...
# 9   A los humanos se le acaba el plazo para evitar...
# 10  Si el clima continúa cambiando a su ritmo actu...
# 11  Cuatro millones de personas se espera que part...
# 12  Un pequeño poblado en el Ártico de Rusia vive ...
# 13  La organización de defensa de los derechos hum...
# 14  La joven activista ambiental sueca Greta Thunb...
# 15  El calentamiento global sigue generando cambio...
#
#                                                themes
# 0   Juventud se manifiesta en cumbre por el clima,...
# 1   Extracción de recursos naturales, Cambio climá...
# 2   Transición entre temporada de lluvias y seca, ...
# 3   Fauna silvestre, Especies en peligro, Especies...
# 4   Grupo río Bogotá, Río Bogotá, Cuenca del Río B...
# 5   Grupo río Bogotá, Humedales de Bogotá, Río Bog...
# 6       Energía, Ecosistema, Biodiversidad, bosques,
# 7   Extinción de osos polares, Osos polares, Osos ...
# 8   Día Nacional de la Biodiversidad, Ana María He...
# 9   Reciclaje, Calentamiento global, Contaminación...
# 10  Pingüinos emperador, Científicos y animales en...
# 11  Greta Thunberg, Huelga mundial por el clima, C...
# 12  Osos polares, Osos polares afectados por el ca...
# 13  Greta Thunberg y cambio climático, Amnistía In...
# 14  Greta Thunberg viajará a América, Greta Thunbe...
# 15  Australia, Cambio climático, Ola de calor, Tem...
# None
# None
# None
#                                                titles  \
# 0   Duque convoca coalición mundial para proteger ...
# 1   Las economías no pueden seguir dependiendo de ...
# 2   Fuertes vientos continuarán este jueves y vier...
# 3   El conflicto del hombre con la fauna silvestre...
# 4   ¿Qué es el Observatorio Ambiental de Bogotá y ...
# 5   Cosquillas en el nido, el libro que enseña tod...
# 6   La generación de energía también puede salvar ...
# 7             Osos polares se extinguirían en 80 años
# 8   "Nuestra supervivencia depende del estado de l...
# 9   Sea un ciudadano más amigable con el medio amb...
# 10  Los pingüinos emperador podrían desaparecer pa...
# 11  Huelga mundial por el clima exigirá acciones r...
# 12  Más de 50 osos polares acechan una aldea en bu...
# 13  Greta Thunberg recibió el premio como embajado...
# 14  Greta Thunberg viajará a América en velero par...
# 15               Australia no tendrá invierno en 2050
# 16  Cuenca del río Tillavá, en el Meta, territorio...
#
#                                             summaries         authors  \
# 0   En su intervención en la Cumbre sobre Bosques ...             ...
# 1   Estudios realizados por analistas de 14 países...             ...
# 2   La transición entre la temporada de lluvias y ...             ...
# 3   Un informe de WWF y el Programa de Naciones Un...             ...
# 4   Esta herramienta de la Secretaría Distrital de...             ...
# 5   Tendrá una versión impresa y otra transmedia p...             ...
# 6   Con el lanzamiento de Enel Biodiversa, este gr...             ...
# 7   Un estudio adelantado por la organización Osos...             ...
# 8   La presidenta de la Plataforma Intergubernamen...             ...
# 9   El mundo requiere acciones urgentes para mitig...             ...
# 10  Investigadores combinaron un modelo climático ...  Mongabay Latam
# 11  Liderada por Greta Thunberg se realizará este ...             ...
# 12  Los animales hambrientos y flacos generaron zo...             ...
# 13  La activista sueca, de 16 años, obtuvo el gala...             ...
# 14  El Malizia II es un yate de alta velocidad que...             ...
# 15  Una nueva herramienta climática indica que en ...             ...
# 16  Delfines rosados, nutrias gigantes, águilas ha...             ...
#
#                        dates  \
# 0   23 de septiembre de 2019
# 1   30 de septiembre de 2019
# 2        27 de junio de 2019
# 3         8 de julio de 2021
# 4        24 de junio de 2021
# 5         9 de junio de 2021
# 6         28 de mayo de 2021
# 7   21 de septiembre de 2020
# 8   11 de septiembre de 2020
# 9    31 de diciembre de 2019
# 10        8 de enero de 2020
# 11    6 de diciembre de 2019
# 12    6 de diciembre de 2019
# 13       22 de julio de 2019
# 14       30 de julio de 2019
# 15       13 de marzo de 2019
# 16         5 de mayo de 2021
#
#                                            paragraphs  \
# 0   Durante su intervención en la Cumbre sobre los...
# 1   Los modelos actuales de producción deben repla...
# 2   Ráfagas de vientos que alcanzan los 30 y hasta...
# 3   El conflicto entre los seres humanos y la vida...
# 4   La pedagogía es una herramienta clave para cre...
# 5   Con más de 540 especies de animales, la cuenca...
# 6   Las apuestas del sector empresarial por trabaj...
# 7   En el mundo solo sobreviven cerca de 26.000 ej...
# 8   Ana María Hernández sueña con un país en térmi...
# 9   A los humanos se le acaba el plazo para evitar...
# 10  Si el clima continúa cambiando a su ritmo actu...
# 11  Cuatro millones de personas se espera que part...
# 12  Un pequeño poblado en el Ártico de Rusia vive ...
# 13  La organización de defensa de los derechos hum...
# 14  La joven activista ambiental sueca Greta Thunb...
# 15  El calentamiento global sigue generando cambio...
# 16  Un clima atípico puso en aprietos la primera e...
#
#                                                themes
# 0   Juventud se manifiesta en cumbre por el clima,...
# 1   Extracción de recursos naturales, Cambio climá...
# 2   Transición entre temporada de lluvias y seca, ...
# 3   Fauna silvestre, Especies en peligro, Especies...
# 4   Grupo río Bogotá, Río Bogotá, Cuenca del Río B...
# 5   Grupo río Bogotá, Humedales de Bogotá, Río Bog...
# 6       Energía, Ecosistema, Biodiversidad, bosques,
# 7   Extinción de osos polares, Osos polares, Osos ...
# 8   Día Nacional de la Biodiversidad, Ana María He...
# 9   Reciclaje, Calentamiento global, Contaminación...
# 10  Pingüinos emperador, Científicos y animales en...
# 11  Greta Thunberg, Huelga mundial por el clima, C...
# 12  Osos polares, Osos polares afectados por el ca...
# 13  Greta Thunberg y cambio climático, Amnistía In...
# 14  Greta Thunberg viajará a América, Greta Thunbe...
# 15  Australia, Cambio climático, Ola de calor, Tem...
# 16  Mamíferos, Delfines rosados, Nutrias en Colomb...
# None
# None
# None
#                                                titles  \
# 0   Duque convoca coalición mundial para proteger ...
# 1   Las economías no pueden seguir dependiendo de ...
# 2   Fuertes vientos continuarán este jueves y vier...
# 3   El conflicto del hombre con la fauna silvestre...
# 4   ¿Qué es el Observatorio Ambiental de Bogotá y ...
# 5   Cosquillas en el nido, el libro que enseña tod...
# 6   La generación de energía también puede salvar ...
# 7             Osos polares se extinguirían en 80 años
# 8   "Nuestra supervivencia depende del estado de l...
# 9   Sea un ciudadano más amigable con el medio amb...
# 10  Los pingüinos emperador podrían desaparecer pa...
# 11  Huelga mundial por el clima exigirá acciones r...
# 12  Más de 50 osos polares acechan una aldea en bu...
# 13  Greta Thunberg recibió el premio como embajado...
# 14  Greta Thunberg viajará a América en velero par...
# 15               Australia no tendrá invierno en 2050
# 16  Cuenca del río Tillavá, en el Meta, territorio...
# 17  “Megaminería y extracción de hidrocarburos, no...
#
#                                             summaries         authors  \
# 0   En su intervención en la Cumbre sobre Bosques ...             ...
# 1   Estudios realizados por analistas de 14 países...             ...
# 2   La transición entre la temporada de lluvias y ...             ...
# 3   Un informe de WWF y el Programa de Naciones Un...             ...
# 4   Esta herramienta de la Secretaría Distrital de...             ...
# 5   Tendrá una versión impresa y otra transmedia p...             ...
# 6   Con el lanzamiento de Enel Biodiversa, este gr...             ...
# 7   Un estudio adelantado por la organización Osos...             ...
# ...
# ..                                                 ...               ...
# 291  Riohacha, Manaure y Uribia, en La Guajira y Va...               ...
# 292  Los bomberos aprovechan la breve tregua que di...               ...
# 293  La ola de calor que afronta este país podría a...               ...
# 294  El Ideam señala que municipios cuya temperatur...               ...
# 295  El fenómeno de El Niño, un patrón climático co...  Redacción Semana
#
#                         dates  \
# 0    23 de septiembre de 2019
# 1    30 de septiembre de 2019
# 2         27 de junio de 2019
# 3          8 de julio de 2021
# 4         24 de junio de 2021
# ..                        ...
# 291   22 de diciembre de 2019
# 292        7 de enero de 2020
# 293   18 de diciembre de 2019
# 294        4 de enero de 2019
# 295      15 de agosto de 2023
#
#                                             paragraphs  \
# 0    Durante su intervención en la Cumbre sobre los...
# 1    Los modelos actuales de producción deben repla...
# 2    Ráfagas de vientos que alcanzan los 30 y hasta...
# 3    El conflicto entre los seres humanos y la vida...
# 4    La pedagogía es una herramienta clave para cre...
# ..                                                 ...
# 291  Altas olas de calor\nTemporada seca\nUnirme al...
# 292  Incendios en Australia\nEfectos de los incendi...
# 293  Ola de calor\nAlza en temperatura mundial\nInc...
# 294  IDEAM\nGirardot\nTolima\nCundinamarca\nBoyacá\...
# 295  Fenómeno de El Niño\nMedioambiente\nClima\ncam...
#
#                                                 themes
# 0    Juventud se manifiesta en cumbre por el clima,...
# 1    Extracción de recursos naturales, Cambio climá...
# 2    Transición entre temporada de lluvias y seca, ...
# 3    Fauna silvestre, Especies en peligro, Especies...
# 4    Grupo río Bogotá, Río Bogotá, Cuenca del Río B...
# ..                                                 ...
# 291              Altas olas de calor, Temporada seca,
# 292  Incendios en Australia, Efectos de los incendi...
# 293  Ola de calor, Alza en temperatura mundial, Inc...
# 294  IDEAM, Girardot, Tolima, Cundinamarca, Boyacá,...
# 295  Fenómeno de El Niño, Medioambiente, Clima, cam...
#
# [296 rows x 6 columns]
# None
# None
# None
#                                                 titles  \
# 0    Duque convoca coalición mundial para proteger ...
# 1    Las economías no pueden seguir dependiendo de ...
# 2    Fuertes vientos continuarán este jueves y vier...
# 3    El conflicto del hombre con la fauna silvestre...
# 4    ¿Qué es el Observatorio Ambiental de Bogotá y ...
# ..                                                 ...
# 292  Bomberos australianos libran batalla contrarre...
# 293  Temperatura en Australia podría acercarse a lo...
# 294  Girardot, a 40 grados: altas temperaturas se r...
# 295  Clima en crisis: las serias consecuencias del ...
# 296  Época de heladas: Las zonas de Colombia en las...
#
#                                              summaries           authors  \
# 0    En su intervención en la Cumbre sobre Bosques ...               ...
# 1    Estudios realizados por analistas de 14 países...               ...
# 2    La transición entre la temporada de lluvias y ...               ...
# 3    Un informe de WWF y el Programa de Naciones Un...               ...
# 4    Esta herramienta de la Secretaría Distrital de...               ...
# ..                                                 ...               ...
# 292  Los bomberos aprovechan la breve tregua que di...               ...
# 293  La ola de calor que afronta este país podría a...               ...
# 294  El Ideam señala que municipios cuya temperatur...               ...
# 295  El fenómeno de El Niño, un patrón climático co...  Redacción Semana
# 296  El Instituto de Hidrología, Meteorología y Est...               ...
#
#                         dates  \
# 0    23 de septiembre de 2019
# 1    30 de septiembre de 2019
# 2         27 de junio de 2019
# 3          8 de julio de 2021
# 4         24 de junio de 2021
# ..                        ...
# 292        7 de enero de 2020
# 293   18 de diciembre de 2019
# 294        4 de enero de 2019
# 295      15 de agosto de 2023
# 296   20 de diciembre de 2018
#
#                                             paragraphs  \
# 0    Durante su intervención en la Cumbre sobre los...
# 1    Los modelos actuales de producción deben repla...
# 2    Ráfagas de vientos que alcanzan los 30 y hasta...
# 3    El conflicto entre los seres humanos y la vida...
# 4    La pedagogía es una herramienta clave para cre...
# ..                                                 ...
# 292  Incendios en Australia\nEfectos de los incendi...
# 293  Ola de calor\nAlza en temperatura mundial\nInc...
# 294  IDEAM\nGirardot\nTolima\nCundinamarca\nBoyacá\...
# 295  Fenómeno de El Niño\nMedioambiente\nClima\ncam...
# 296  Fenómeno de El niño\nHeladas\nIDEAM\nUnirme al...
#
#                                                 themes
# 0    Juventud se manifiesta en cumbre por el clima,...
# 1    Extracción de recursos naturales, Cambio climá...
# 2    Transición entre temporada de lluvias y seca, ...
# 3    Fauna silvestre, Especies en peligro, Especies...
# 4    Grupo río Bogotá, Río Bogotá, Cuenca del Río B...
# ..                                                 ...
# 292  Incendios en Australia, Efectos de los incendi...
# 293  Ola de calor, Alza en temperatura mundial, Inc...
# 294  IDEAM, Girardot, Tolima, Cundinamarca, Boyacá,...
# 295  Fenómeno de El Niño, Medioambiente, Clima, cam...
# 296              Fenómeno de El niño, Heladas, IDEAM,
#
# [297 rows x 6 columns]
# None
# None
# None
#                                                 titles  \
# 0    Duque convoca coalición mundial para proteger ...
# 1    Las economías no pueden seguir dependiendo de ...
# 2    Fuertes vientos continuarán este jueves y vier...
# 3    El conflicto del hombre con la fauna silvestre...
# 4    ¿Qué es el Observatorio Ambiental de Bogotá y ...
# ..                                                 ...
# 293  Temperatura en Australia podría acercarse a lo...
# 294  Girardot, a 40 grados: altas temperaturas se r...
# 295  Clima en crisis: las serias consecuencias del ...
# 296  Época de heladas: Las zonas de Colombia en las...
# 297  Mientras el frío azota a América del Norte, en...
#
#                                              summaries           authors  \
# 0    En su intervención en la Cumbre sobre Bosques ...               ...
# 1    Estudios realizados por analistas de 14 países...               ...
# 2    La transición entre la temporada de lluvias y ...               ...
# 3    Un informe de WWF y el Programa de Naciones Un...               ...
# 4    Esta herramienta de la Secretaría Distrital de...               ...
# ..                                                 ...               ...
# 293  La ola de calor que afronta este país podría a...               ...
# 294  El Ideam señala que municipios cuya temperatur...               ...
# 295  El fenómeno de El Niño, un patrón climático co...  Redacción Semana
# 296  El Instituto de Hidrología, Meteorología y Est...               ...
# 297  Se emitieron advertencias de incendios en el á...               ...
#
#                         dates  \
# 0    23 de septiembre de 2019
# 1    30 de septiembre de 2019
# 2         27 de junio de 2019
# 3          8 de julio de 2021
# 4         24 de junio de 2021
# ..                        ...
# 293   18 de diciembre de 2019
# 294        4 de enero de 2019
# 295      15 de agosto de 2023
# 296   20 de diciembre de 2018
# 297        7 de enero de 2018
#
#                                             paragraphs  \
# 0    Durante su intervención en la Cumbre sobre los...
# 1    Los modelos actuales de producción deben repla...
# 2    Ráfagas de vientos que alcanzan los 30 y hasta...
# 3    El conflicto entre los seres humanos y la vida...
# 4    La pedagogía es una herramienta clave para cre...
# ..                                                 ...
# 293  Ola de calor\nAlza en temperatura mundial\nInc...
# 294  IDEAM\nGirardot\nTolima\nCundinamarca\nBoyacá\...
# 295  Fenómeno de El Niño\nMedioambiente\nClima\ncam...
# 296  Fenómeno de El niño\nHeladas\nIDEAM\nUnirme al...
# 297  Alclima\nCambio climático\nUnirme al canal de ...
#
#                                                 themes
# 0    Juventud se manifiesta en cumbre por el clima,...
# 1    Extracción de recursos naturales, Cambio climá...
# 2    Transición entre temporada de lluvias y seca, ...
# 3    Fauna silvestre, Especies en peligro, Especies...
# 4    Grupo río Bogotá, Río Bogotá, Cuenca del Río B...
# ..                                                 ...
# 293  Ola de calor, Alza en temperatura mundial, Inc...
# 294  IDEAM, Girardot, Tolima, Cundinamarca, Boyacá,...
# 295  Fenómeno de El Niño, Medioambiente, Clima, cam...
# 296              Fenómeno de El niño, Heladas, IDEAM,
# 297                        Alclima, Cambio climático,
#
# [298 rows x 6 columns]
# None
# None
# None
#                                                 titles  \
# 0    Duque convoca coalición mundial para proteger ...
# 1    Las economías no pueden seguir dependiendo de ...
# 2    Fuertes vientos continuarán este jueves y vier...
# 3    El conflicto del hombre con la fauna silvestre...
# 4    ¿Qué es el Observatorio Ambiental de Bogotá y ...
# ..                                                 ...
# 294  Girardot, a 40 grados: altas temperaturas se r...
# 295  Clima en crisis: las serias consecuencias del ...
# 296  Época de heladas: Las zonas de Colombia en las...
# 297  Mientras el frío azota a América del Norte, en...
# 298  Increíble: se registró la misma temperatura en...
#
#                                              summaries           authors  \
# 0    En su intervención en la Cumbre sobre Bosques ...               ...
# 1    Estudios realizados por analistas de 14 países...               ...
# 2    La transición entre la temporada de lluvias y ...               ...
# 3    Un informe de WWF y el Programa de Naciones Un...               ...
# 4    Esta herramienta de la Secretaría Distrital de...               ...
# ..                                                 ...               ...
# 294  El Ideam señala que municipios cuya temperatur...               ...
# 295  El fenómeno de El Niño, un patrón climático co...  Redacción Semana
# 296  El Instituto de Hidrología, Meteorología y Est...               ...
# 297  Se emitieron advertencias de incendios en el á...               ...
# 298  El pasado miércoles se dio una inusual situaci...               ...
#
#                         dates  \
# 0    23 de septiembre de 2019
# 1    30 de septiembre de 2019
# 2         27 de junio de 2019
# 3          8 de julio de 2021
# 4         24 de junio de 2021
# ..                        ...
# 294        4 de enero de 2019
# 295      15 de agosto de 2023
# 296   20 de diciembre de 2018
# 297        7 de enero de 2018
# 298        2 de marzo de 2017
#
#                                             paragraphs  \
# 0    Durante su intervención en la Cumbre sobre los...
# 1    Los modelos actuales de producción deben repla...
# 2    Ráfagas de vientos que alcanzan los 30 y hasta...
# 3    El conflicto entre los seres humanos y la vida...
# 4    La pedagogía es una herramienta clave para cre...
# ..                                                 ...
# 294  IDEAM\nGirardot\nTolima\nCundinamarca\nBoyacá\...
# 295  Fenómeno de El Niño\nMedioambiente\nClima\ncam...
# 296  Fenómeno de El niño\nHeladas\nIDEAM\nUnirme al...
# 297  Alclima\nCambio climático\nUnirme al canal de ...
# 298  Antártida\nTemperatura\nNOAA\nDesierto\nÁfrica...
#
#                                                 themes
# 0    Juventud se manifiesta en cumbre por el clima,...
# 1    Extracción de recursos naturales, Cambio climá...
# 2    Transición entre temporada de lluvias y seca, ...
# 3    Fauna silvestre, Especies en peligro, Especies...
# 4    Grupo río Bogotá, Río Bogotá, Cuenca del Río B...
# ..                                                 ...
# 294  IDEAM, Girardot, Tolima, Cundinamarca, Boyacá,...
# 295  Fenómeno de El Niño, Medioambiente, Clima, cam...
# 296              Fenómeno de El niño, Heladas, IDEAM,
# 297                        Alclima, Cambio climático,
# 298  Antártida, Temperatura, NOAA, Desierto, África...
#
# [299 rows x 6 columns]
#                                                 titles  \
# 0    Duque convoca coalición mundial para proteger ...
# 1    Las economías no pueden seguir dependiendo de ...
# 2    Fuertes vientos continuarán este jueves y vier...
# 3    El conflicto del hombre con la fauna silvestre...
# 4    ¿Qué es el Observatorio Ambiental de Bogotá y ...
# ..                                                 ...
# 295  Clima en crisis: las serias consecuencias del ...
# 296  Época de heladas: Las zonas de Colombia en las...
# 297  Mientras el frío azota a América del Norte, en...
# 298  Increíble: se registró la misma temperatura en...
# 299                                                ...
#
#                                              summaries           authors  \
# 0    En su intervención en la Cumbre sobre Bosques ...               ...
# 1    Estudios realizados por analistas de 14 países...               ...
# 2    La transición entre la temporada de lluvias y ...               ...
# 3    Un informe de WWF y el Programa de Naciones Un...               ...
# 4    Esta herramienta de la Secretaría Distrital de...               ...
# ..                                                 ...               ...
# 295  El fenómeno de El Niño, un patrón climático co...  Redacción Semana
# 296  El Instituto de Hidrología, Meteorología y Est...               ...
# 297  Se emitieron advertencias de incendios en el á...               ...
# 298  El pasado miércoles se dio una inusual situaci...               ...
# 299                                                ...               ...
#
#                         dates  \
# 0    23 de septiembre de 2019
# 1    30 de septiembre de 2019
# 2         27 de junio de 2019
# 3          8 de julio de 2021
# 4         24 de junio de 2021
# ..                        ...
# 295      15 de agosto de 2023
# 296   20 de diciembre de 2018
# 297        7 de enero de 2018
# 298        2 de marzo de 2017
# 299                       ...
#
#                                             paragraphs  \
# 0    Durante su intervención en la Cumbre sobre los...
# 1    Los modelos actuales de producción deben repla...
# 2    Ráfagas de vientos que alcanzan los 30 y hasta...
# 3    El conflicto entre los seres humanos y la vida...
# 4    La pedagogía es una herramienta clave para cre...
# ..                                                 ...
# 295  Fenómeno de El Niño\nMedioambiente\nClima\ncam...
# 296  Fenómeno de El niño\nHeladas\nIDEAM\nUnirme al...
# 297  Alclima\nCambio climático\nUnirme al canal de ...
# 298  Antártida\nTemperatura\nNOAA\nDesierto\nÁfrica...
# 299                                                ...
#
#                                                 themes
# 0    Juventud se manifiesta en cumbre por el clima,...
# 1    Extracción de recursos naturales, Cambio climá...
# 2    Transición entre temporada de lluvias y seca, ...
# 3    Fauna silvestre, Especies en peligro, Especies...
# 4    Grupo río Bogotá, Río Bogotá, Cuenca del Río B...
# ..                                                 ...
# 295  Fenómeno de El Niño, Medioambiente, Clima, cam...
# 296              Fenómeno de El niño, Heladas, IDEAM,
# 297                        Alclima, Cambio climático,
# 298  Antártida, Temperatura, NOAA, Desierto, África...
# 299                                                ...
#
# [300 rows x 6 columns]

# %%
df_news_clean = df.drop_duplicates(subset=["titles"])

# %%
df_news_clean.to_csv("df_news/df_news_clean_2.csv")

# %%
# Variable para definir el final de tiempo en ejecución
end = time.time()

# Variable para calcular tiempo y para enviar a la función
result = end-start

#Impresión del tiempo que tardó
print(Seconds(result))
# Out:
# El sitema tardó: 0 horas 25 minutos 24 segundos en finalizar su ejeción

# %%
df_news_clean
# Out:
#                                                 titles  \
# 0    Duque convoca coalición mundial para proteger ...
# 1    Las economías no pueden seguir dependiendo de ...
# 2    Fuertes vientos continuarán este jueves y vier...
# 3    El conflicto del hombre con la fauna silvestre...
# 4    ¿Qué es el Observatorio Ambiental de Bogotá y ...
# ..                                                 ...
# 295  Clima en crisis: las serias consecuencias del ...
# 296  Época de heladas: Las zonas de Colombia en las...
# 297  Mientras el frío azota a América del Norte, en...
# 298  Increíble: se registró la misma temperatura en...
# 299                                                ...
#
#                                              summaries           authors  \
# 0    En su intervención en la Cumbre sobre Bosques ...               ...
# 1    Estudios realizados por analistas de 14 países...               ...
# 2    La transición entre la temporada de lluvias y ...               ...
# 3    Un informe de WWF y el Programa de Naciones Un...               ...
# 4    Esta herramienta de la Secretaría Distrital de...               ...
# ..                                                 ...               ...
# 295  El fenómeno de El Niño, un patrón climático co...  Redacción Semana
# 296  El Instituto de Hidrología, Meteorología y Est...               ...
# 297  Se emitieron advertencias de incendios en el á...               ...
# 298  El pasado miércoles se dio una inusual situaci...               ...
# 299                                                ...               ...
#
#                         dates  \
# 0    23 de septiembre de 2019
# 1    30 de septiembre de 2019
# 2         27 de junio de 2019
# 3          8 de julio de 2021
# 4         24 de junio de 2021
# ..                        ...
# 295      15 de agosto de 2023
# 296   20 de diciembre de 2018
# 297        7 de enero de 2018
# 298        2 de marzo de 2017
# 299                       ...
#
#                                             paragraphs  \
# 0    Durante su intervención en la Cumbre sobre los...
# 1    Los modelos actuales de producción deben repla...
# 2    Ráfagas de vientos que alcanzan los 30 y hasta...
# 3    El conflicto entre los seres humanos y la vida...
# 4    La pedagogía es una herramienta clave para cre...
# ..                                                 ...
# 295  Fenómeno de El Niño\nMedioambiente\nClima\ncam...
# 296  Fenómeno de El niño\nHeladas\nIDEAM\nUnirme al...
# 297  Alclima\nCambio climático\nUnirme al canal de ...
# 298  Antártida\nTemperatura\nNOAA\nDesierto\nÁfrica...
# 299                                                ...
#
#                                                 themes
# 0    Juventud se manifiesta en cumbre por el clima,...
# 1    Extracción de recursos naturales, Cambio climá...
# 2    Transición entre temporada de lluvias y seca, ...
# 3    Fauna silvestre, Especies en peligro, Especies...
# 4    Grupo río Bogotá, Río Bogotá, Cuenca del Río B...
# ..                                                 ...
# 295  Fenómeno de El Niño, Medioambiente, Clima, cam...
# 296              Fenómeno de El niño, Heladas, IDEAM,
# 297                        Alclima, Cambio climático,
# 298  Antártida, Temperatura, NOAA, Desierto, África...
# 299                                                ...
#
# [299 rows x 6 columns]
